# %%
# !pip install pandas
# !pip install simple_salesforce
from matchingFunctions import *

# %%
sf = createSalesforceConnection()

# %%
cases = createCaseDF(sf)

# %%
suppliers = createSupplierDF(sf)

# %%
objectxs = createObjectxDF(sf)

# %%
objectxsFiltered = mergeAndFilterObjXs(objectxs, suppliers, cases)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
laboredge = createLaboredgeDF()

# %%
##files = createFileDF()
files = pd.DataFrame()

# %%
laboredgeMerged = createLaboredgeMergedDF(laboredge, objectxsFiltered, files)

# %%
laboredgeMatched = createLaboredgeMatchedDF(laboredgeMerged)

# %%
objectxs.to_csv('prevObjectXs.csv')
objectxsFiltered.to_csv('prevObjectXsFiltered.csv')
laboredge.to_csv('prevLaboredge.csv')
laboredgeMerged.to_csv('prevLaboredgeMerged.csv')
laboredgeMatched.to_csv('laboredgeMatched.csv')

# %%
laboredgeMerged[laboredgeMerged['Object X ID'].isnull() != False]
# Out:
# Empty DataFrame
# Columns: [Deal Date, Case #, Client, Service Provider, OEM Company, Product/Category, Level, Position Title, Hours, exp Low, exp High, Country, City/State, qtd Low, qtd High, tgt Low, tgt High, Deal Total, Currency Notes, Document Name, Service Provider U, Object X ID]
# Index: []
#
# [0 rows x 22 columns]

# %%
laboredgeMatched.sort_values('Input Date')
# Out:
#
# 4602                                   NaN   NaN
# 6906                                   NaN   NaN
# 11468                                  NaN   NaN
# 6972                                   NaN   NaN
# 14480                                  NaN   NaN
# 14539                                  NaN   NaN
# ...                                    ...   ...
# 4937                                   NaN   NaN
# 10616                                  NaN   NaN
# 4939                                   NaN   NaN
# 23705                                  NaN   NaN
# 24020                                  NaN   NaN
# 10064                                  NaN   NaN
# 11716                                  NaN   NaN
# 10351                                  NaN   NaN
# 4938                                   NaN   NaN
# 24102                                  NaN   NaN
# 14252                                  NaN   NaN
# 6898                                   NaN   NaN
# ...
